# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter

# you can use the class Counter to count the number of examples in each category

count = Counter([t.category for t in tests])
count

# eg. of spanning questions are like - 'How many people has a salary above 60k' -> these questions RAG have a hard time with because the answers are not in a specific chunk
# comparative -> 'Who's been around in Insurllm for longer'
# holistic -> questions that pertains to everything as a whole, you need to read the whole documents to understand (RAG struggles with this the most.)
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)  # this is the judging the retrieval only
# the result shows that keywords_found is 2, out of 3 total_keywords
# mrr and keyword_coverage are the go-to metrics for RAG
# Out:
# RetrievalEval(mrr=0.6666666666666666, ndcg=0.5561086263536886, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)  # using llm as a judge

# %%
eval
# Out:
# AnswerEval(feedback='The generated answer correctly identifies Maxine as the winner of the IIOTY award in 2023, matching the name and award title from the reference. However, it adds extra information about her role and company, which is not asked for. The core information about her winning is accurate and relevant, but the additional details slightly affect relevance and completeness.', accuracy=5.0, completeness=4.0, relevance=4.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The generated answer correctly identifies Maxine as the winner of the IIOTY award in 2023, matching the name and award title from the reference. However, it adds extra information about her role and company, which is not asked for. The core information about her winning is accurate and relevant, but the additional details slightly affect relevance and completeness.
# 5.0
# 4.0
# 4.0
