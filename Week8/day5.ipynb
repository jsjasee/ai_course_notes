# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal
# Out:
# /Users/tayjiasheng/AI Projects/llm_engineering/.venv/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.3.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:
    with gr.Row():
        gr.Markdown(
            '<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>'
        )
    with gr.Row():
        gr.Markdown(
            '<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>'
        )


ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:
    initial_deal = Deal(
        product_description="Example description", price=100.0, url="https://cnn.com"
    )
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [
            [
                opp.deal.product_description,
                opp.deal.price,
                opp.estimate,
                opp.discount,
                opp.deal.url,
            ]
            for opp in opps
        ]

    with gr.Row():
        gr.Markdown(
            '<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>'
        )
    with gr.Row():
        gr.Markdown(
            '<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>'
        )
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:
    initial_deal = Deal(
        product_description="Example description", price=100.0, url="https://cnn.com"
    )
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [
            [
                opp.deal.product_description,
                opp.deal.price,
                opp.estimate,
                opp.discount,
                opp.deal.url,
            ]
            for opp in opps
        ]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown(
            '<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>'
        )
    with gr.Row():
        gr.Markdown(
            '<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>'
        )
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(
        get_table, inputs=[opportunities], outputs=[opportunities_dataframe]
    )  # this means when the ui loads, call the function get_table() to see the deals
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)
# Out:
# [2026-05-31 22:15:22 +0800] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] Use pytorch device_name: mps
# [2026-05-31 22:15:23 +0800] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-05-31 22:15:27 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-05-31 22:15:27 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-05-31 22:15:27 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-05-31 22:15:27 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-05-31 22:15:27 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-05-31 22:15:27 +0800] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code

# %%
# Reset memory back to 2 deals discovered in the past

from deal_agent_framework import DealAgentFramework

DealAgentFramework.reset_memory()  # delete the memory down to 2 entries that got surfaced.

# %%
import logging

root = logging.getLogger()
root.setLevel(logging.INFO)

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!

# %%
# !uv run price_is_rightv2.py
# Out:
# /Users/tayjiasheng/AI Projects/llm_engineering/.venv/lib/python3.12/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.3.0) or chardet (6.0.0.post1)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] Use pytorch device_name: mps
# [2026-06-01 12:01:27 +0800] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] Kicking off Planning Agent
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-06-01 12:01:32 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-06-01 12:02:12 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:02:13 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent received 26 deals not already scraped
# [2026-06-01 12:02:13 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-06-01 12:02:23 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-06-01 12:02:23 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:02:23 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:02:23 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:02:23 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:02:27 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:02:27 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:02:27 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:02:27 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:02:41 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:02:42 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:02:42 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:02:43 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:03:12 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-06-01 12:03:12 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:01<00:00,  1.32s/it]
# [2026-06-01 12:03:14 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:03:14 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:03:15 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $53.50
# [2026-06-01 12:03:15 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $54.80
# [2026-06-01 12:03:15 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $37.80
# [2026-06-01 12:03:15 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:03:15 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:03:15 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:03:15 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:03:23 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:23 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:23 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:03:23 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:03:24 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $189.00
# [2026-06-01 12:03:24 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  2.66it/s]
# [2026-06-01 12:03:25 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:03:25 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:03:26 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $169.99
# [2026-06-01 12:03:26 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $173.79
# [2026-06-01 12:03:26 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $71.79
# [2026-06-01 12:03:26 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:03:26 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:03:26 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:03:26 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:03:33 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:33 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:33 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:03:33 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:03:34 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $90.00
# [2026-06-01 12:03:34 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  3.61it/s]
# [2026-06-01 12:03:35 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:03:35 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:03:36 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $125.00
# [2026-06-01 12:03:36 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $118.00
# [2026-06-01 12:03:36 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $22.00
# [2026-06-01 12:03:36 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:03:36 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:03:36 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:03:36 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:03:39 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:39 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:39 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:03:39 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:03:40 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-06-01 12:03:40 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  3.78it/s]
# [2026-06-01 12:03:41 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:03:41 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:03:48 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $139.99
# [2026-06-01 12:03:48 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $133.99
# [2026-06-01 12:03:48 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $73.50
# [2026-06-01 12:03:48 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:03:48 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:03:48 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:03:48 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:03:54 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:54 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:03:54 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:03:54 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:03:56 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2026-06-01 12:03:56 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  1.65it/s]
# [2026-06-01 12:03:57 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:03:57 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:03:58 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $899.00
# [2026-06-01 12:03:58 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $909.20
# [2026-06-01 12:03:58 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-90.80
# [2026-06-01 12:03:58 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $73.50
# [2026-06-01 12:03:59 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:03:59 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-06-01 12:03:59 +0800] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Wielio Mini Projector runs Android 11 with built-in app access and supports 1080p playback while accepting 4K content, producing up to 240 ANSI lumens of brightness. It features a low-noise cooling system under 30 dB and is designed for home media streaming and portable projection. The unit includes typical projector interfaces and app-driven streaming functionality for easy setup and use in small to medium rooms.', price=60.49, url='https://www.dealnews.com/Hangzhou-Xinhongyang-Jidian-Extended-Placement-8-Days-Wielio-Mini-Projector-for-60-free-shipping/21836478.html?iref=rss-c39') estimate=133.99200000000002 discount=73.50200000000001
# [2026-06-01 12:08:59 +0800] [Agents] [INFO] Kicking off Planning Agent
# [2026-06-01 12:08:59 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-06-01 12:08:59 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-06-01 12:09:33 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent received 25 deals not already scraped
# [2026-06-01 12:09:33 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-06-01 12:09:43 +0800] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-06-01 12:09:43 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:09:43 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:09:43 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:09:43 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:09:47 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:09:47 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:09:47 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:09:47 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:10:20 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# [2026-06-01 12:10:20 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:01<00:00,  1.02s/it]
# [2026-06-01 12:10:21 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:10:21 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:10:22 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $360.00
# [2026-06-01 12:10:22 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $332.00
# [2026-06-01 12:10:22 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $99.00
# [2026-06-01 12:10:22 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:10:22 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:10:22 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:10:22 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:10:27 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:27 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:27 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:10:27 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:10:28 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $700.00
# [2026-06-01 12:10:28 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  6.37it/s]
# [2026-06-01 12:10:29 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:10:29 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:10:30 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1199.00
# [2026-06-01 12:10:30 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $1099.20
# [2026-06-01 12:10:30 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $99.20
# [2026-06-01 12:10:30 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:10:30 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:10:30 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:10:30 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:10:35 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:35 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:35 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:10:35 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:10:36 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-06-01 12:10:36 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  3.85it/s]
# [2026-06-01 12:10:36 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:10:36 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:10:37 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $34.99
# [2026-06-01 12:10:37 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $39.99
# [2026-06-01 12:10:37 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $30.60
# [2026-06-01 12:10:37 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:10:37 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:10:37 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:10:37 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:10:40 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:40 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:40 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:10:40 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:10:42 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# [2026-06-01 12:10:42 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  9.51it/s]
# [2026-06-01 12:10:42 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:10:42 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:10:43 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $349.99
# [2026-06-01 12:10:43 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $323.99
# [2026-06-01 12:10:43 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $173.99
# [2026-06-01 12:10:43 +0800] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-06-01 12:10:43 +0800] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 12:10:43 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# [2026-06-01 12:10:43 +0800] [Agents] [INFO]
# LiteLLM completion() model= openai/gpt-oss-20b; provider = openrouter
# 12:10:49 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:49 +0800] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-06-01 12:10:49 +0800] [Agents] [INFO] [Ensemble Agent] Pre-processed text using openrouter/openai/gpt-oss-20b
# [2026-06-01 12:10:49 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-06-01 12:10:50 +0800] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-06-01 12:10:50 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  2.22it/s]
# [2026-06-01 12:10:51 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-06-01 12:10:51 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-5.1 with context including 5 similar products
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $1099.00
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $979.20
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-258.80
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $173.99
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-06-01 12:10:52 +0800] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='Certified Refurbished iRobot Roomba j7+ is a self-emptying robot vacuum that includes smart mapping, obstacle avoidance, and a self-cleaning cartridge filter. The j7+ model automatically deposits dirt into its base bin, supports scheduling and mapping features via the iRobot app, and is refurbished and backed by a two-year Allstate warranty for extended coverage.', price=150.0, url='https://www.dealnews.com/products/iRobot/iRobot-Roomba-j7-Self-Emptying-Robot-Vacuum/455442.html?iref=rss-f1912') estimate=323.992 discount=173.99200000000002
# ^C
# Traceback (most recent call last):
#   File "/Users/tayjiasheng/AI Projects/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2958, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tayjiasheng/AI Projects/llm_engineering/week8/price_is_rightv2.py", line 241, in <module>
#     App().run()
#   File "/Users/tayjiasheng/AI Projects/llm_engineering/week8/price_is_rightv2.py", line 237, in run
#     ui.launch(share=False, inbrowser=True)
#   File "/Users/tayjiasheng/AI Projects/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2865, in launch
#     self.block_thread()
#   File "/Users/tayjiasheng/AI Projects/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2962, in block_thread
#     self.server.close()
#   File "/Users/tayjiasheng/AI Projects/llm_engineering/.venv/lib/python3.12/site-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/Users/tayjiasheng/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/Users/tayjiasheng/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#a22;">But wait!! There's more..</h2>
#             <span style="color:#a22;">If you're not fed up of product prices yet 😂 I've built this out some more!<br/>
#             If you look in my repo <a href="https://github.com/ed-donner/tech2ai">tech2ai</a>, in segment4 is a version that uses OpenAI Agents SDK for the AutonomousPlanningAgent, and makes use of MCP servers.  If you're intrigued by Agents and MCP, and would like to learn more, then I also have a companion course on this. This, along with my 2 other companion courses, are laid out in my <a href="https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/">complete AI curriculum</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">CONGRATULATIONS AND THANK YOU!!!</h2>
#             <span style="color:#090;">
#                 It's so fabulous that you've made it to the very end! My heartiest congratulations. Please stay in touch! I'm <a href="https://www.linkedin.com/in/eddonner/">here on LinkedIn</a> if we're not already connected and I'm on X at <a href="https://x.com/edwarddonner">@edwarddonner</a>. And my editor would be cross with me if I didn't mention one more time: it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. <br/><br/>Massive thanks again for putting up with me for 8 weeks and getting all the way to the final cell! I'm excited to hear all about your career as an LLM Engineer. If you post on LinkedIn about completing the course and tag me, then I'll weigh in to amplify your achievement. <br/><b>You could not have picked a better time to be in this field.</b>
#             </span>
#         </td>
#     </tr>
# </table>
